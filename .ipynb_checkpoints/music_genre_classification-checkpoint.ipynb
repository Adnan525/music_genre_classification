# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import librosa
import librosa.display
import IPython.display as ipd
import warnings
warnings.filterwarnings("ignore")

# %%
# datset exploration
folder_file_counts = {}

for root, dirs, files in os.walk("music_genre_dataset/Data/images_original/"):
    print(root)
    print(len(files))
# Out:
# music_genre_dataset/Data/images_original/
# 0
# music_genre_dataset/Data/images_original/blues
# 100
# music_genre_dataset/Data/images_original/classical
# 100
# music_genre_dataset/Data/images_original/country
# 100
# music_genre_dataset/Data/images_original/disco
# 100
# music_genre_dataset/Data/images_original/hiphop
# 100
# music_genre_dataset/Data/images_original/jazz
# 99
# music_genre_dataset/Data/images_original/metal
# 100
# music_genre_dataset/Data/images_original/pop
# 100
# music_genre_dataset/Data/images_original/reggae
# 100
# music_genre_dataset/Data/images_original/rock
# 100

# %% [markdown]
# # We will be working directly with music files, we have wav files in the datset

# %%
# testing with 1 file
file, sample_rate = librosa.load("music_genre_dataset/Data/genres_original/blues/blues.00000.wav")
file, sample_rate, file.shape
# Out:
# (array([ 0.00732422,  0.01660156,  0.00762939, ..., -0.05560303,
#         -0.06106567, -0.06417847], dtype=float32),
#  22050,
#  (661794,))

# %%
# trim to get rid of silent parts if any
target_audio, index = librosa.effects.trim(file)
target_audio.shape
# Out:
# (661794,)

# %%
# show the audio file
plt.figure(figsize = (20, 5))
librosa.display.waveshow(y = target_audio)
